# %%
import os
from dotenv import load_dotenv
import pandas as pd

# %%
# import requests

# load_dotenv()
# api_key=os.getenv("RAPIDKEY")

# url = "https://real-time-amazon-data.p.rapidapi.com/products-by-category"

# querystring = {"category_id":"281407","page":"1","country":"US","sort_by":"RELEVANCE","product_condition":"ALL","is_prime":"false","deals_and_discounts":"NONE"}

# headers = {
# 	"x-rapidapi-key": api_key,
# 	"x-rapidapi-host": "real-time-amazon-data.p.rapidapi.com",
# 	"Content-Type": "application/json"
# }

# response = requests.get(url, headers=headers, params=querystring)

# print(response.json())
# Out:
# {'status': 'OK', 'request_id': '3ecb6ebb-c90e-4e6d-933b-1bbb270bcc88', 'parameters': {'category_id': '281407', 'country': 'US', 'sort_by': 'RELEVANCE', 'page': 1, 'is_prime': False, 'language': 'en_US'}, 'data': {'total_products': 71523, 'country': 'US', 'domain': 'www.amazon.com', 'products': [{'asin': 'B0FDQK69GQ', 'product_title': 'Ailun 3 Pack Screen Protector for iPhone 17 Pro Max [6.9 inch] with Installation Frame, Tempered Glass, Sensor Protection, Dynamic Island Compatible, Case Friendly Global Recycled Standard', 'product_price': '$6.99', 'product_original_price': None, 'currency': 'USD', 'product_star_rating': '4.6', 'product_num_ratings': 1133761, 'product_url': 'https://www.amazon.com/dp/B0FDQK69GQ', 'product_photo': 'https://m.media-amazon.com/images/I/71XuFtl2aBL._AC_UL960_QL65_.jpg', 'product_num_offers': 3, 'product_minimum_offer_price': '$6.97', 'is_best_seller': False, 'is_amazon_choice': False, 'is_prime': True, 'climate_pledge_friendly': True, 'sales_volume': '10K
# ...

# %%
movies = []

for i in range(1, 429):
    response = requests.get(
        f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}'
    )

    movies.extend(response.json()['results'])

df = pd.DataFrame(movies)[
    ['id', 'title', 'overview', 'release_date',
     'popularity', 'vote_average', 'vote_count']
]

print(df.shape)

# %%
products = []

for i in range(1, 10):
    url = "https://real-time-amazon-data.p.rapidapi.com/products-by-category"

    querystring = {"category_id":"281407","page":f"{i}","country":"US","sort_by":"RELEVANCE","product_condition":"ALL","is_prime":"false","deals_and_discounts":"NONE"}

    headers = {
        "x-rapidapi-key": api_key,
        "x-rapidapi-host": "real-time-amazon-data.p.rapidapi.com",
        "Content-Type": "application/json"
    }

    response = requests.get(url, headers=headers, params=querystring)
    products.extend(response.json()['data']['products'])


df = pd.DataFrame(movies)[
    ['id', 'title', 'overview', 'release_date',
     'popularity', 'vote_average', 'vote_count']
]

print(df.shape)

# %%
df= pd.DataFrame(response.json()['data']['products'])[['asin'	,'product_title'	,'product_price'	,'product_original_price'	,'currency'	,'product_star_rating'	,'product_num_ratings' ,'product_url'	,'product_photo']]
df
# Out:
#           asin                                      product_title  \
# 0   B0FDQK69GQ  Ailun 3 Pack Screen Protector for iPhone 17 Pr...
# 1   B0FQFB8FMG  Apple AirPods Pro 3 Wireless Earbuds, Active N...
# 2   B0GYHK91TK  Portable Mini Bluetooth Speaker with HD Sound,...
# 3   B0F1YGC8KB  USB C Fast Charger Block, 60W USBC Wall Charge...
# 4   B0GWQ9GDLX  USB C Car Charger, 2Pack 60W Dual USB C Adapte...
# 5   B0F3J4WBZV  Braided Stretchy Band Compatible with Apple Wa...
# 6   B0H1W5KZ82  5 Pack Upgraded USB C Headphones for iPhone 17...
# 7   B0GX61ZFX2  iPhone Charger Cable 10FT, 2Pack USB C to Ligh...
# 8   B0GJBHZ3PP  USB-A to Lightning Cable 3.3FT Fast Woven Char...
# 9   B0GGXT83K9  USB-C and Lightning to HDMI Adapter, 4K@60Hz M...
# 10  B0FQ1N1YFG  Stylus Pen for Touchscreen 10PCS, AGREJO High ...
# 11  B0GR9D61CQ  2Pack for iPhone Charger Cable 3FT, Lightning ...
# 12  B0FHW7S6HM  2 Pack 6.6FT PS5 Controller Charger Cable, USB...
# ...

# %%
df.to_csv('amazon.csv')
