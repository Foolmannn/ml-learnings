# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %% [markdown]
# # 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 2. How does the data look like?

# %%
df.sample(5)  # it is better approach than df.head() as sampling removes the misconception that might occur due to bias. For ex all the first rows might be similar to each other leading to half understanding of data
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 178          179         0       2                         Hale, Mr. Reginald
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 346          347         1       2                  Smith, Miss. Marion Elsie
# 78            79         1       2              Caldwell, Master. Alden Gates
# 825          826         0       3                            Flynn, Mr. John
#
#         Sex    Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 178    male  30.00      0      0  250653  13.00   NaN        S
# 829  female  62.00      0      0  113572  80.00   B28      NaN
# 346  female  40.00      0      0   31418  13.00   NaN        S
# 78     male   0.83      0      2  248738  29.00   NaN        S
# 825    male    NaN      0      0  368323   6.95   NaN        Q

# %% [markdown]
# # 3. What is the data type of cols?

# %%
df.info()

# %% [markdown]
# # 4. Are there any missing values?

# %%
df.isnull().sum()

# %% [markdown]
# # 5. How does the data look mathematically?

# %%
df.describe()

# %% [markdown]
# # 6. Are there duplicate values?

# %%
df.duplicated().sum()

# %% [markdown]
# # 7. How is the correlation between cols?

# %%
df.corr()['Survived']
