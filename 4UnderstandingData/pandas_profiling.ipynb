# %%
# !pip install pandas-profiling

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 271          272         1       3   Tornquist, Mr. William Henry    male
# 642          643         0       3  Skoog, Miss. Margit Elizabeth  female
# 811          812         0       3              Lester, Mr. James    male
# 464          465         0       3             Maisner, Mr. Simon    male
# 322          323         1       2      Slayter, Miss. Hilda Mary  female
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 271  25.0      0      0       LINE   0.00   NaN        S
# 642   2.0      3      2     347088  27.90   NaN        S
# 811  39.0      0      0  A/4 48871  24.15   NaN        S
# 464   NaN      0      0   A/S 2816   8.05   NaN        S
# 322  30.0      0      0     234818  12.35   NaN        Q

# %%
# from pandas_profiling import ProfileReport
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file('output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5529.74it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
