# %%
# !pip install pandas-profiling

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 695          696         0       2          Chapman, Mr. Charles Henry
# 795          796         0       2                  Otter, Mr. Richard
# 813          814         0       3  Andersson, Miss. Ebba Iris Alfrida
# 213          214         0       2         Givard, Mr. Hans Kristensen
# 37            38         0       3            Cann, Mr. Ernest Charles
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 695    male  52.0      0      0      248731  13.500   NaN        S
# 795    male  39.0      0      0       28213  13.000   NaN        S
# 813  female   6.0      4      2      347082  31.275   NaN        S
# 213    male  30.0      0      0      250646  13.000   NaN        S
# 37     male  21.0      0      0  A./5. 2152   8.050   NaN        S

# %%
# from pandas_profiling import ProfileReport
from data_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file('output.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # from pandas_profiling import ProfileReport
# ----> 2 from data_profiling import ProfileReport
#       3 prof = ProfileReport(df)
#       4 prof.to_file('output.html')
#
# File ~/miniconda3/envs/ml312/lib/python3.12/site-packages/data_profiling/__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from data_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from data_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from data_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~/miniconda3/envs/ml312/lib/python3.12/site-packages/data_profiling/compare_reports.py:12
#      10 from data_profiling.model import BaseDescription
#      11 from data_profiling.model.alerts import Alert
# ---> 12 from data_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~/miniconda3/envs/ml312/lib/python3.12/site-packages/data_profiling/profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'
