# %%
import numpy as np

# %% [markdown]
# O D array / scaler

# %%
a = np.array(4)
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %% [markdown]
# 1D array / array / Vector

# %%
b=np.array([1,2,3,4])
print(b)
b.ndim
# Out:
# [1 2 3 4]
# 1

# %% [markdown]
# This above b is vector ie 1D array or 1D tensors. But is has 4 dimensions.
# [1,2] is 1D tensor with two/2 dimensions

# %% [markdown]
# Axis equals to no of dimenstion for ex. 2 D array has 2 axis
#
# No of axis is also called the Rank or dimension of tensors

# %% [markdown]
# And one thing is the 1D tensors is collections of 0 D tensors or scalers. And 2 D tensors is the collections of the 1D tensors

# %% [markdown]
# 2D Tensors/ 2 D arrays / Matrices

# %%
c=np.array([[1,2,4],[5,6,7]])
c.ndim
# Out:
# 2

# %%
c
# Out:
# array([[1, 2, 4],
#        [5, 6, 7]])

# %%
Above is the 2D tensors.

# %% [markdown]
# 3D tensors / ND tensors :
#
# 3 D is the collections of the 2 D tensors and so on.
#
# So 3 D tensors will be the stack of the matrices ie cuboid like shape.
#
# And 4 D tensor will be the collections of the cuboids on row or column(only one )
#
#  And 5D tensors will be the matrix of the 4D tensors ie rows and columns of the 4 D martix

# %% [markdown]
# Rank = no. of axis = No of dimensions
#
#
# For ex 3 X 3 matix:
#
# it is 2D tensors ie 2 axis.
#
# Shape is max no of items that can be stored in tensors
#
# For this 3*3 will store 9 . So its shape is 9
#
#
# And for 2 X 3 matrices. Shape will be the 6 although the 2 D tensors and rank, ndim is 2 . Shape can be different
#
# For scaler : shape / size is 1
#
# For other we have to multiply

# %%
c.shape
# Out:
# (2, 3)
