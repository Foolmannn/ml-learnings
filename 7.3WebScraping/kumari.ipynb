# %%
import pandas as pd

import requests

from bs4 import BeautifulSoup

# url = "https://www.kumarijob.com/"

# webpage = requests.get(url).text

# soup = BeautifulSoup(webpage, 'html.parser')


# container = soup.find_all('div', class_="position-relative")

# %%
url="https://www.jobsnepal.com/jobs?page=2"
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 Chrome/126.0 Safari/537.36"
    )
}

webpage = requests.get(url, headers=headers).text
soup=BeautifulSoup(webpage,'html.parser')
# soup.prettify()

# %%
# soup.prettify()

# %%
# title = soup.find('a',class_="job-info").text
# print(title)
# Out:
#                                                 Sales Coordinator

# %%
container = soup.find_all('div',class_="card-body")
# print(container)

# %%
len(container)
# Out:
# 12

# %%
# print(container)

for data in container:
    title= data.find('h2',class_="job-title").text
    print(title)
    # company=data.find('a',class_="group-card-title").text
    # print(company)
    # location= data.find('div',class_="date").text
    # print(location)
    # salary= data.find('div',class_="salary").text
    # print(salary)
    list = data.find_all('li')
    print(list[0].text.strip())
    print(list[1].text.strip())
    print(list[2].text.strip())

        # print(item.text.strip())
# Out:
#                         Field Supervisor
#
#
# HURENDEC
# Kalikot
# Agriculture, Development Project, NGO/INGO/Social work
#
#
#                         Request for Quotation for Consultancy service for Transcription/Translation of Audio and SRT files
#
#
# Mercy Corps
# Lalitpur
# Development Project, Expression of Interests, Tender Notice, Bid
#
#
#                         कर्मचारी आवश्यकता सम्बन्धी सूचना
#
#
# National Farmers Group Federation Nepal (NFGF Nepal)
# Kathmandu
# Administrative / Management, Public Health, Development Project, Medical / Nursing, Human Rights, Logistics / Procurement
#
#
#                         बोलपत्र सम्बन्धी सूचना (Stationery Materials-HA Flood)
#
#
# SOS Children's Villages Nepal
# Bhaktapur
# Development Project, Expression of Interests, Tender Notice, Bid
#
#
#                         कर्मचारी पदपूर्ति सम्बन्धि सूचना
#
#
# Sundar Nepal Sanstha (BNA), surkhet
# Birendranagar Surkhet
# ...
