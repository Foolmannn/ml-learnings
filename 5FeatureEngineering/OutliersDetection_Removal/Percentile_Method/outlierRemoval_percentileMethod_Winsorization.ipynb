# %% [markdown]
# ## Outlier Detection using the Percentile Method

# %% [markdown]
# In this method we choose the percentile threshold value mostly 1 . Ie all the values below the 1 percentile and above 99 percentile are considered outliers and handled accordingly.

# %% [markdown]
# Capping done with the percentile method is called  Winsorization

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
import seaborn as sns

# %%
sns.histplot(df['Height'],kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %% [markdown]
# Taking 1 percentile as the threshold

# %%
upper_limit = df['Height'].quantile(0.99)
upper_limit
# Out:
# np.float64(74.7857900583366)

# %%
lower_limit = df['Height'].quantile(0.01)
lower_limit
# Out:
# np.float64(58.13441158671655)

# %%
new_df = df[(df['Height'] <= 74.78) & (df['Height'] >= 58.13)]

# %%
new_df['Height'].describe()
# Out:
# count    9799.000000
# mean       66.363507
# std         3.644267
# min        58.134496
# 25%        63.577147
# 50%        66.317899
# 75%        69.119859
# max        74.767447
# Name: Height, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.displot(new_df['Height'],kind='kde')

# %%
sns.boxplot(new_df['Height'])

# %%
# Capping --> Winsorization
df['Height'] = np.where(df['Height'] >= upper_limit,
        upper_limit,
        np.where(df['Height'] <= lower_limit,
        lower_limit,
        df['Height']))

# %%
df.shape

# %%
df['Height'].describe()

# %%
sns.distplot(df['Height'])

# %%
sns.boxplot(df['Height'])
