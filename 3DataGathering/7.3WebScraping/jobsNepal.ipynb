# %%
import pandas as pd

import requests

from bs4 import BeautifulSoup

# url = "https://www.kumarijob.com/"

# webpage = requests.get(url).text

# soup = BeautifulSoup(webpage, 'html.parser')


# container = soup.find_all('div', class_="position-relative")

# %%
# url="https://www.jobsnepal.com/jobs?page=2"
# headers = {
#     "User-Agent": (
#         "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
#         "AppleWebKit/537.36 Chrome/126.0 Safari/537.36"
#     )
# }

# webpage = requests.get(url, headers=headers).text
# soup=BeautifulSoup(webpage,'html.parser')
# soup.prettify()

# %%
# soup.prettify()

# %%
# title = soup.find('a',class_="job-info").text
# print(title)
# Out:
#                                                 Sales Coordinator

# %%
# container = soup.find_all('div',class_="card-body")
# print(container)

# %%
len(container)
# Out:
# 12

# %%
# # print(container)
# jobTitle=[]
# companyName=[]
# address=[]
# info=[]


# for data in container:
#     title= data.find('h2',class_="job-title").text.strip()
#     print(title)
#     # company=data.find('a',class_="group-card-title").text
#     # print(company)
#     # location= data.find('div',class_="date").text
#     # print(location)
#     # salary= data.find('div',class_="salary").text
#     # print(salary)
#     list = data.find_all('li')
#     # print(list[0].text.strip())
#     # print(list[1].text.strip())
#     # print(list[2].text.strip())
#     print(len(title))
#     if len(title)<30:
#         jobTitle.append(title)
#         companyName.append(list[0].text.strip())
#         address.append(list[1].text.strip())
#         info.append(list[2].text.strip())



#         # print(item.text.strip())

# %%
# print(jobTitle)

# %%
jobTitle=[]
companyName=[]
address=[]
info=[]

for i in range(1,15):
    url=f"https://www.jobsnepal.com/jobs?page={i}"
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 Chrome/126.0 Safari/537.36"
        )
    }

    webpage = requests.get(url, headers=headers).text
    soup=BeautifulSoup(webpage,'html.parser')


    container = soup.find_all('div',class_="card-body")




    for data in container:
        title= data.find('h2',class_="job-title").text.strip()
        list = data.find_all('li')
        if len(title)<30 and len(list)==3:
            print(len(list))
            jobTitle.append(title)
            companyName.append(list[0].text.strip())
            address.append(list[1].text.strip())
            info.append(list[2].text.strip())
# Out:
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3

# %%
print(jobTitle)
print(info)
# Out:
# ['Communication Officer', 'Various Positions', 'Field Supervisor', 'Various Positions', 'Program Manager', 'Various Positions', 'NOTICE FOR BID', 'Various Positions', 'Call for consultant', 'Call for consultant', 'Textile & General Sourcing', 'Clinic Incharge', 'Expression of Interest (EOI)', 'Various Positions', 'FARM HOUSE WORKER REQUIRED', 'Sales and Marketing', 'TENDER NOTICE', 'SENIOR RESEARCH ASSOCIATE', 'Driver Cum Messenger', 'Technical Support', 'Karjanha Construction', 'Request for Quotation', 'Dietitian', 'Vacancy Announcement', 'Health Assistant (HA) or CMA', 'BIM Engineer/Specialist', 'Civil Structural Engineer', 'Quality Control Officer', 'Sales Executive', 'Invitation for Bid', 'Supervisor', 'Request for Bid-Notice', 'Agriculture Field Officer', 'Intern', 'बोलपत्रको सूचना आह्वान', 'Sales Person', 'Terms of Reference', 'REQUEST FOR PROPOSALS', 'Paid Internship / Jobs', 'Request for Quotation (RFQ)', 'Client Success Officer', 'Call for Tourism Experts', 'Expression of In
# ...

# %% [markdown]
# Now form the data frame

# %%
dic={'JobTitle':jobTitle,'CompanyName':companyName,'Location':address,'Responsibilities':info}
df = pd.DataFrame(dic)

# %%
df
# Out:
#                          JobTitle  \
# 0           Communication Officer
# 1               Various Positions
# 2                Field Supervisor
# 3               Various Positions
# 4                 Program Manager
# 5               Various Positions
# 6                  NOTICE FOR BID
# 7               Various Positions
# 8             Call for consultant
# 9             Call for consultant
# 10     Textile & General Sourcing
# 11                Clinic Incharge
# 12   Expression of Interest (EOI)
# 13              Various Positions
# 14     FARM HOUSE WORKER REQUIRED
# 15            Sales and Marketing
# 16                  TENDER NOTICE
# 17      SENIOR RESEARCH ASSOCIATE
# 18           Driver Cum Messenger
# 19              Technical Support
# 20          Karjanha Construction
# 21          Request for Quotation
# 22                      Dietitian
# 23           Vacancy Announcement
# 24   Health Assistant (HA) or CMA
# 25        BIM Engineer/Specialist
# ...

# %% [markdown]
# As this site is not that good in the html consistency we are getting this wrong values in some place
