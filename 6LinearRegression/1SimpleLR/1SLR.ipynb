# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../placements.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:,0:1]
y= df.iloc[:,-1]

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 40   9.38
# 51   9.26
# 139  7.19
# 197  7.21
# 170  6.22
# 82   5.58
# 183  7.28
# 46   6.07
# 70   5.79
# 100  7.95
# 179  7.14
# 83   8.44
# 25   7.28
# 190  6.19
# 159  8.71
# 173  6.75
# 95   6.63
# 3    7.42
# 41   6.89
# 58   6.92
# 14   7.73
# 143  4.85
# 12   8.94
# 6    6.73
# 182  5.88
# 161  7.30
# 128  7.93
# 122  5.12
# 101  6.71
# 86   7.61
# 64   7.36
# 47   5.84
# 158  5.95
# 34   7.34
# 38   8.62
# 196  5.89
# 4    6.94
# 72   7.78
# 67   6.51
# 145  5.84

# %%
y_test
# Out:
# 40     4.02
# 51     3.79
# 139    2.40
# 197    3.24
# 170    2.87
# 82     2.17
# 183    2.72
# 46     2.26
# 70     2.35
# 100    4.14
# 179    3.03
# 83     3.49
# 25     3.65
# 190    2.69
# 159    4.08
# 173    2.56
# 95     2.79
# 3      3.67
# 41     2.70
# 58     3.09
# 14     3.42
# 143    1.54
# 12     3.65
# 6      2.60
# 182    2.08
# 161    3.33
# 128    3.34
# 122    2.01
# 101    3.52
# 86     2.77
# 64     2.92
# 47     3.26
# 158    3.04
# 34     3.42
# 38     4.36
# 196    2.57
# 4      3.57
# 72     3.62
# 67     2.89
# 145    2.18
# Name: package, dtype: float64

# %% [markdown]
# ### Testing the few values from the test data

# %%
# first cgpa 9.38 and actual package is 4.02 
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /home/foolmann/miniconda3/envs/ml312/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.39751239])

# %%
# Second test value 
lr.predict(X_test.iloc[1].values.reshape(1,1))
# Out:
# /home/foolmann/miniconda3/envs/ml312/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.32680345])

# %% [markdown]
# We can see that it is not that exact of the prediction

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color="red") # line derived the algorithm 
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
# this is the slope values
m=lr.coef_
m
# Out:
# array([0.5892411])

# %%
# Intercept ie b value 
b= lr.intercept_
b
# Out:
# np.float64(-1.1295691481499253)

# %%
# showing the prediction 

m * 9.38 + b

# this 4.39 is the predicted value
# Out:
# array([4.39751239])

# %%
# new data prediction 
m* 9.5 + b
# Out:
# array([4.46822132])
